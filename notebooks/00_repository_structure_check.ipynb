# %% [markdown]
# # Repository Structure Check
#
# Starter notebook for validating the Bangladesh MPO School & College Salary Tax Toolkit repository structure.

# %%
from pathlib import Path
root = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
required = ['data', 'docs', 'excel', 'metadata', 'notebooks', 'release', 'scripts', 'tests', 'wiki']
{name: (root / name).exists() for name in required}
